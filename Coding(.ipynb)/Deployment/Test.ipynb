# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture(os.path.join('SUMMARIZE_ABBREVIATE_CONDENSE.mp4'))

# %%
ret, frame = cap.read()

# %%
frame
# Out:
# array([[[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [217, 220, 220],
#         [217, 220, 220],
#         [217, 220, 220]],
#
#        ...,
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [235, 224, 228],
#         [235, 224, 228],
#         [235, 224, 228]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
#         ...,
#         [231, 220, 224],
#         [231, 220, 224],
#         [231, 220, 224]],
#
#        [[235, 235, 235],
#         [235, 235, 235],
#         [235, 235, 235],
# ...

# %%
frame.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 cv2.cvtColor(frame)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - cvtColor() missing required argument 'code' (pos 2)
# >  - cvtColor() missing required argument 'code' (pos 2)
